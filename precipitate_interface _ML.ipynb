# %% [markdown]
# ## Imports
#   * Importing pandas, numpy, matplotlib, seaborn and other sklearn tools

# %%
import numpy as np, seaborn as sns, pandas as pd, matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import math

# %% [markdown]
# ## Get the Data
# * Read in the finaldata.csv file as a DataFrame called df.
#
# * finaldata.csv: Contains the data of radial distance at every 5 degree and corresponding Epsilon and Gamma values

# %%
data = pd.DataFrame(pd.read_csv('finaldata.csv'))
data.head()
# Out:
#        E  Gamma     Theta0     Theta5    Theta10    Theta15    Theta20  \
# 0  0.000    0.3  34.886311  34.888082  34.902252  34.907094  34.920904
# 1  0.005    0.3  35.066715  35.053381  35.031217  34.991246  34.947822
# 2  0.010    0.3  35.249462  35.226130  35.160270  35.071395  34.967780
# 3  0.015    0.3  35.434116  35.399546  35.288556  35.146914  34.980623
# 4  0.020    0.3  35.623962  35.571879  35.418418  35.213445  34.986557
#
#      Theta25    Theta30    Theta35  ...   Theta315   Theta320   Theta325  \
# 0  34.935860  34.953338  34.962089  ...  34.972915  34.971094  34.961749
# 1  34.905296  34.865515  34.832645  ...  34.805978  34.813256  34.832321
# 2  34.867797  34.775222  34.705271  ...  34.643359  34.656734  34.704974
# 3  34.824423  34.683589  34.579774  ...  34.484960  34.508322  34.579523
# 4  34.776679  34.591237  34.455261  ...  34.335852  34.366611  34.455066
#
#     Theta330   Theta335   Theta340   Theta345   Theta350   Theta355   Theta360
# ...

# %% [markdown]
# ## Training and Testing Data
#
# * Now we split the data into training and testing sets.
# * Setting a variable X equal to the numerical features of the data ( E , Gamma ) and a variable y equal to the radial distance
# * Using **model_selection.train_test_split** from sklearn to split the data into training and testing sets.
# * Setting **test_size=0.3** which divides total data into training and testing data in the ratio of 70% and 30% respectively
# * For training the data, we are use **LinearRegression model**, using this we create a model named lm and then fit our training data in this model
# * After this we predict the test data using this trained model

# %%
X= data[['E' , 'Gamma']]
y =data[['Theta0', 'Theta5', 'Theta10', 'Theta15', 'Theta20','Theta25', 'Theta30', 'Theta35', 'Theta40', 'Theta45', 'Theta50','Theta55', 'Theta60', 'Theta65', 'Theta70', 'Theta75', 'Theta80','Theta85', 'Theta90', 'Theta95', 'Theta100', 'Theta105', 'Theta110','Theta115', 'Theta120', 'Theta125', 'Theta130', 'Theta135', 'Theta140','Theta145', 'Theta150', 'Theta155', 'Theta160', 'Theta165', 'Theta170','Theta175', 'Theta180', 'Theta185', 'Theta190', 'Theta195', 'Theta200','Theta205', 'Theta210', 'Theta215', 'Theta220', 'Theta225', 'Theta230','Theta235', 'Theta240', 'Theta245', 'Theta250', 'Theta255', 'Theta260','Theta265', 'Theta270', 'Theta275', 'Theta280', 'Theta285', 'Theta290','Theta295', 'Theta300', 'Theta305', 'Theta310', 'Theta315', 'Theta320','Theta325', 'Theta330', 'Theta335', 'Theta340', 'Theta345', 'Theta350','Theta355','Theta360']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
lm = LinearRegression()
lm.fit(X_train,y_train)
predictions = lm.predict(X_test)

# %% [markdown]
# ## Evaluating the Model
# * Comparing predicted values with test data
# * Calculating the Mean Absolute Error, Mean Squared Error, and the Root Mean Squared Error and R2 Score

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
print('R2 SCORE:' , metrics.r2_score(y_test,predictions))
# Out:
# MAE: 0.014219011153231778
# MSE: 0.00030050028435393974
# RMSE: 0.017334944025117004
# R2 SCORE: 0.9565135926126593

# %%
# %matplotlib inline
plt.figure(figsize=(6,6))
plt.scatter(y_test,predictions)
plt.xlabel('y_test', fontsize = 18)
plt.ylabel('predictions',fontsize = 18)
plt.title('Model Performance')
plt.show()

# %% [markdown]
# ## Validation
#
# * Taking a random Epsilon value as E =0.0374654 and gamma = 0.3
# * And passing this data to our model to predict the radial diatance
# * And then ploitng this data with theoratical data

# %%
Test_case = lm.predict([[0.0374654, 0.3]])
Test_case
# Out:
# array([[36.38992175, 36.17960712, 35.77875849, 35.34388603, 34.93028577,
#         34.57718178, 34.2888809 , 34.07820684, 33.95160272, 33.90888358,
#         33.95160272, 34.07820684, 34.2888809 , 34.57718178, 34.93028577,
#         35.34388603, 35.77875852, 36.17960766, 36.38992175, 36.17964282,
#         35.7787999 , 35.34393651, 34.93034437, 34.57724981, 34.28895068,
#         34.07828219, 33.9516839 , 33.90896331, 33.95168387, 34.07828375,
#         34.28895408, 34.57725128, 34.9303493 , 35.34394195, 35.7788053 ,
#         36.17964396, 36.38991053, 36.17958383, 35.77873036, 35.34385747,
#         34.93025705, 34.57714995, 34.28885294, 34.07817667, 33.95157492,
#         33.90885507, 33.95157492, 34.07817667, 34.28885294, 34.57714995,
#         34.93025705, 35.34385747, 35.77873036, 36.17958383, 36.38991053,
#         36.17964396, 35.7788053 , 35.34394195, 34.9303493 , 34.57725128,
#         34.28895408, 34.07828375, 33.95168387, 33.90896331, 33.9516839 ,
# ...

# %%
df2 = np.array(pd.read_csv('Real_data.csv')) #importing Theoretical data

# %% [markdown]
# ## Plot
# * Plot of predicted shape and thoratical shape overlap on each other.

# %%
plt.figure(figsize=(10,10))
ax = plt.subplot(111, projection='polar')
ax.plot(np.radians(np.arange(0,361,5)), Test_case[0,:] , marker='*',markersize=10)
ax.plot(np.radians(np.arange(0,361,5)), df2[0][3:],marker = 'o')
ax.grid(False)
ax.set_title("Precipitate Contour Shape at Phi=0.5 for E =0.0374654", va='bottom',fontsize = 15)
plt.legend(['Predicted','Theoretical'],fontsize = 15)
plt.show()
